# %% [markdown]
# # TP2 - Pattern Composite
#
# Ce TP porte sur l'implémentation du pattern Composite.

# %% [markdown]
# ## 1. Diagramme de classe :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Interface Piece:

# %%
public interface Piece {
    String nom;
    double getPrix();
}

# %% [markdown]
# * Classe Piece de base:

# %%
public class PieceDeBase implements Piece { 
    private String nem; 
    private double prixunitaire;
    public PieceDeBase(String non, double prixunitaire){
        this. nom = nom;
        this.prixunitaire = prixunitaire; 
    }
    public String getBom(){
        return nom; 
    }  
    @Override
    public double getPrix() {
        return prixUnitaire;
    }
}

# %% [markdown]
# * Classe Piece Composite

# %%
import java.util.ArrayList; import java.util.List; 
public class Piececomposite implements Piece {
    private String III; 
    private double prixAssemblage; 
    private ListePiece> pieces = new ArrayList<>(); 
    public Piececomposite(String double prixAssemblage) {
        this.nom = nom; 
        this.prixAssemblage = prixAssemblage;
    } 
    public void ajouterPiece(Piece piece) { 
        pieces.add(piece);
    } 
    @Override
    public double getPrix() {
        double prixTotal = prixAssemblage; 
        for (Piece piece pieces) { 
            prixTotal += piece.getPrix();
        } 
        return prixTotal;
    } 
}

# %% [markdown]
# * Classe StockManager:

# %%
public class StockManager {
    private List<Piece> stock = new ArrayList<>();

    public void ajouterPiece(Piece piece) {
        stock.add(piece);
    }

    public double calculerValeurStock() {
        double valeurTotale = 0;
        for (Piece piece : stock) {
            valeurTotale += piece.getPrix();
        }
        return valeurTotale;
    }

    public void afficherStock() {
        for (Piece piece : stock) {
            System.out.println("Nom: " + piece.getNom() + ", Prix: " + piece.getPrix());
        }
    }
}

# %% [markdown]
# ## 2. Diagramme de Séquence

# %% [markdown]
# ![image.png](attachment:image.png)
